# %% [markdown]
# # Trajectory analysis notebook - density profile
# In this notebook we show how the MDAnalysis package can be used to perform some _basic_ analysis of the simulations using the atomic trajectory generated by openMM (or any other MD package).

# %%
# Packages for the trajectory analysis and visualisation
import MDAnalysis as md
import nglview as ng

# python packages
import pandas as pd                  # Dataframes and reading CSV files
import numpy as np                   # Numerical libraries
import matplotlib.pyplot as plt      # Plotting library
from lmfit import Model              # Least squares fitting library
from scipy.optimize import curve_fit # Alternative curve fittting library
# Out:
# /Users/237454k/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/coordinates/chemfiles.py:108: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   MIN_CHEMFILES_VERSION = LooseVersion("0.9")
# /Users/237454k/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/coordinates/TRJ.py:1209: DeprecationWarning: Please use `netcdf_file` from the `scipy.io` namespace, the `scipy.io.netcdf` namespace is deprecated.
#   class NCDFPicklable(scipy.io.netcdf.netcdf_file):

# %% [markdown]
# For simplicity we define three variables that represent the three Cartesian directions.

# %%
X = 0
Y = 1
Z = 2

# %% [markdown]
# First of all we have to load the trajectory. In this case the trajectory was written in the _CHARMM_ DCD format, which is binary (not ASCII) _i.e._ not human-readable, which is done to save storage space. Indeed classical MD simulations can generate very large trajectories, and storage can become an issue. Moreover, the DCD file contains only the coordinates and no information about the atoms' type. Hence, we have to use an auxiliary file to retrieve that info, in this case the PDB files. This approach is also normal to many visualisation tools.

# %%
sys = md.Universe("mix.pdb", 'trajectory.1.dcd')
# md.topology.guessers.guess_atom_element("Ar")
nFrames = len(sys.trajectory)
print("Number of Frames : %4i" % nFrames)
# Out:
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Input In [3], in <cell line: 1>()
# ----> 1 sys = md.Universe("mix.pdb", 'trajectory.1.dcd')
#       2 # md.topology.guessers.guess_atom_element("Ar")
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/core/universe.py:336, in Universe.__init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, in_memory, in_memory_step, *coordinates, **kwargs)
#     335     self.filename = _check_file_like(topology)
# --> 336     topology = _topology_from_file_like(self.filename,
#     337                                         topology_format=topology_format,
#     338                                         **kwargs)
#     340 if topology is not None:
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/core/universe.py:130, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     127 if (err.errno is not None and
#     128     errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     129     # Runs if the error is propagated due to no permission / file not found
# --> 130     raise sys.exc_info()[1] from err
#     131 else:
#     132     # Runs when the parser fails
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/core/universe.py:122, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     121     with parser(topology_file) as p:
# --> 122         topology = p.parse(**kwargs)
#     123 except (IOError, OSError) as err:
#     124     # There are 2 kinds of errors that might be raised here:
#     125     # one because the file isn't present
#     126     # or the permissions are bad, second when the parser fails
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/topology/PDBParser.py:199, in PDBParser.parse(self, **kwargs)
#     193 """Parse atom information from PDB file
#     194
#     195 Returns
#     196 -------
#     197 MDAnalysis Topology object
#     198 """
# --> 199 top = self._parseatoms()
#     201 try:
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/topology/PDBParser.py:234, in PDBParser._parseatoms(self)
#     233 last_wrapped_serial = 100000  # if serials wrap, start from here
# --> 234 with util.openany(self.filename) as f:
#     235     for line in f:
#
# File ~/miniconda3/envs/work/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/util.py:315, in openany(datasource, mode, reset)
#     273 """Context manager for :func:`anyopen`.
#     274
#     275 Open the `datasource` and close it when the context of the :keyword:`with`
#    (...)
#     313 :func:`anyopen`
#     314 """
# --> 315 stream = anyopen(datasource, mode=mode, reset=reset)
#     316 try:
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/util.py:394, in anyopen(datasource, mode, reset)
#     393 openfunc = read_handlers[ext]
# --> 394 stream = _get_stream(datasource, openfunc, mode=mode)
#     395 if stream is not None:
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/util.py:436, in _get_stream(filename, openfunction, mode)
#     435 if errno.errorcode[err.errno] in ['ENOENT', 'EACCES']:
# --> 436     raise sys.exc_info()[1] from err
#     437 return None
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/util.py:430, in _get_stream(filename, openfunction, mode)
#     429 try:
# --> 430     stream = openfunction(filename, mode=mode)
#     431 except (IOError, OSError) as err:
#     432     # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#     433     # case we have to ignore the error and return None. Second is when openfunction can't open the file because
#     434     # either the file isn't there or the permissions don't allow access.
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py:478, in bz2_pickle_open(name, mode)
#     477 bz_mode = mode.replace("t", "")
# --> 478 binary_file = BZ2Picklable(name, bz_mode)
#     479 if "t" in mode:
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py:266, in BZ2Picklable.__init__(self, name, mode)
#     265 self._bz_mode = mode
# --> 266 super().__init__(name, mode)
#
# File ~/miniconda3/envs/work/lib/python3.9/bz2.py:85, in BZ2File.__init__(self, filename, mode, compresslevel)
#      84 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 85     self._fp = _builtin_open(filename, mode)
#      86     self._closefp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mix.pdb'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Input In [3], in <cell line: 1>()
# ----> 1 sys = md.Universe("mix.pdb", 'trajectory.1.dcd')
#       2 # md.topology.guessers.guess_atom_element("Ar")
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/core/universe.py:336, in Universe.__init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, in_memory, in_memory_step, *coordinates, **kwargs)
#     335     self.filename = _check_file_like(topology)
# --> 336     topology = _topology_from_file_like(self.filename,
#     337                                         topology_format=topology_format,
#     338                                         **kwargs)
#     340 if topology is not None:
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/core/universe.py:130, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     127 if (err.errno is not None and
#     128     errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     129     # Runs if the error is propagated due to no permission / file not found
# --> 130     raise sys.exc_info()[1] from err
#     131 else:
#     132     # Runs when the parser fails
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/core/universe.py:122, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     121     with parser(topology_file) as p:
# --> 122         topology = p.parse(**kwargs)
#     123 except (IOError, OSError) as err:
#     124     # There are 2 kinds of errors that might be raised here:
#     125     # one because the file isn't present
#     126     # or the permissions are bad, second when the parser fails
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/topology/PDBParser.py:199, in PDBParser.parse(self, **kwargs)
#     193 """Parse atom information from PDB file
#     194
#     195 Returns
#     196 -------
#     197 MDAnalysis Topology object
#     198 """
# --> 199 top = self._parseatoms()
#     201 try:
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/topology/PDBParser.py:234, in PDBParser._parseatoms(self)
#     233 last_wrapped_serial = 100000  # if serials wrap, start from here
# --> 234 with util.openany(self.filename) as f:
#     235     for line in f:
#
# File ~/miniconda3/envs/work/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/util.py:315, in openany(datasource, mode, reset)
#     273 """Context manager for :func:`anyopen`.
#     274
#     275 Open the `datasource` and close it when the context of the :keyword:`with`
#    (...)
#     313 :func:`anyopen`
#     314 """
# --> 315 stream = anyopen(datasource, mode=mode, reset=reset)
#     316 try:
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/util.py:394, in anyopen(datasource, mode, reset)
#     393 openfunc = read_handlers[ext]
# --> 394 stream = _get_stream(datasource, openfunc, mode=mode)
#     395 if stream is not None:
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/util.py:436, in _get_stream(filename, openfunction, mode)
#     435 if errno.errorcode[err.errno] in ['ENOENT', 'EACCES']:
# --> 436     raise sys.exc_info()[1] from err
#     437 return None
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/util.py:430, in _get_stream(filename, openfunction, mode)
#     429 try:
# --> 430     stream = openfunction(filename, mode=mode)
#     431 except (IOError, OSError) as err:
#     432     # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#     433     # case we have to ignore the error and return None. Second is when openfunction can't open the file because
#     434     # either the file isn't there or the permissions don't allow access.
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py:478, in bz2_pickle_open(name, mode)
#     477 bz_mode = mode.replace("t", "")
# --> 478 binary_file = BZ2Picklable(name, bz_mode)
#     479 if "t" in mode:
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py:266, in BZ2Picklable.__init__(self, name, mode)
#     265 self._bz_mode = mode
# --> 266 super().__init__(name, mode)
#
# File ~/miniconda3/envs/work/lib/python3.9/bz2.py:85, in BZ2File.__init__(self, filename, mode, compresslevel)
#      84 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 85     self._fp = _builtin_open(filename, mode)
#      86     self._closefp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mix.pdb'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 sys = md.Universe("mix.pdb", 'trajectory.1.dcd')
#       2 # md.topology.guessers.guess_atom_element("Ar")
#       3 nFrames = len(sys.trajectory)
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/core/universe.py:336, in Universe.__init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, in_memory, in_memory_step, *coordinates, **kwargs)
#     334 if not isinstance(topology, Topology) and not topology is None:
#     335     self.filename = _check_file_like(topology)
# --> 336     topology = _topology_from_file_like(self.filename,
#     337                                         topology_format=topology_format,
#     338                                         **kwargs)
#     340 if topology is not None:
#     341     self._topology = topology
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/core/universe.py:130, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     123 except (IOError, OSError) as err:
#     124     # There are 2 kinds of errors that might be raised here:
#     125     # one because the file isn't present
#     126     # or the permissions are bad, second when the parser fails
#     127     if (err.errno is not None and
#     128         errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     129         # Runs if the error is propagated due to no permission / file not found
# --> 130         raise sys.exc_info()[1] from err
#     131     else:
#     132         # Runs when the parser fails
#     133         raise IOError("Failed to load from the topology file {0}"
#     134                         " with parser {1}.\n"
#     135                         "Error: {2}".format(topology_file, parser, err))
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/core/universe.py:122, in _topology_from_file_like(topology_file, topology_format, **kwargs)
#     120 try:
#     121     with parser(topology_file) as p:
# --> 122         topology = p.parse(**kwargs)
#     123 except (IOError, OSError) as err:
#     124     # There are 2 kinds of errors that might be raised here:
#     125     # one because the file isn't present
#     126     # or the permissions are bad, second when the parser fails
#     127     if (err.errno is not None and
#     128         errno.errorcode[err.errno] in ['ENOENT', 'EACCES']):
#     129         # Runs if the error is propagated due to no permission / file not found
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/topology/PDBParser.py:199, in PDBParser.parse(self, **kwargs)
#     192 def parse(self, **kwargs):
#     193     """Parse atom information from PDB file
#     194
#     195     Returns
#     196     -------
#     197     MDAnalysis Topology object
#     198     """
# --> 199     top = self._parseatoms()
#     201     try:
#     202         bonds = self._parsebonds(top.ids.values)
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/topology/PDBParser.py:234, in PDBParser._parseatoms(self)
#     232 self._wrapped_serials = False  # did serials go over 100k?
#     233 last_wrapped_serial = 100000  # if serials wrap, start from here
# --> 234 with util.openany(self.filename) as f:
#     235     for line in f:
#     236         line = line.strip()  # Remove extra spaces
#
# File ~/miniconda3/envs/work/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/util.py:315, in openany(datasource, mode, reset)
#     271 @contextmanager
#     272 def openany(datasource, mode='rt', reset=True):
#     273     """Context manager for :func:`anyopen`.
#     274
#     275     Open the `datasource` and close it when the context of the :keyword:`with`
#    (...)
#     313     :func:`anyopen`
#     314     """
# --> 315     stream = anyopen(datasource, mode=mode, reset=reset)
#     316     try:
#     317         yield stream
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/util.py:394, in anyopen(datasource, mode, reset)
#     392 for ext in ('bz2', 'gz', ''):  # file == '' should be last
#     393     openfunc = read_handlers[ext]
# --> 394     stream = _get_stream(datasource, openfunc, mode=mode)
#     395     if stream is not None:
#     396         break
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/util.py:436, in _get_stream(filename, openfunction, mode)
#     431 except (IOError, OSError) as err:
#     432     # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#     433     # case we have to ignore the error and return None. Second is when openfunction can't open the file because
#     434     # either the file isn't there or the permissions don't allow access.
#     435     if errno.errorcode[err.errno] in ['ENOENT', 'EACCES']:
# --> 436         raise sys.exc_info()[1] from err
#     437     return None
#     438 if mode.startswith('r'):
#     439     # additional check for reading (eg can we uncompress) --- is this needed?
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/util.py:430, in _get_stream(filename, openfunction, mode)
#     428 """Return open stream if *filename* can be opened with *openfunction* or else ``None``."""
#     429 try:
# --> 430     stream = openfunction(filename, mode=mode)
#     431 except (IOError, OSError) as err:
#     432     # An exception might be raised due to two reasons, first the openfunction is unable to open the file, in this
#     433     # case we have to ignore the error and return None. Second is when openfunction can't open the file because
#     434     # either the file isn't there or the permissions don't allow access.
#     435     if errno.errorcode[err.errno] in ['ENOENT', 'EACCES']:
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py:478, in bz2_pickle_open(name, mode)
#     475     raise ValueError("Only read mode ('r', 'rt', 'rb') "
#     476                      "files can be pickled.")
#     477 bz_mode = mode.replace("t", "")
# --> 478 binary_file = BZ2Picklable(name, bz_mode)
#     479 if "t" in mode:
#     480     return TextIOPicklable(binary_file)
#
# File ~/miniconda3/envs/work/lib/python3.9/site-packages/MDAnalysis/lib/picklable_file_io.py:266, in BZ2Picklable.__init__(self, name, mode)
#     264 def __init__(self, name, mode='rb'):
#     265     self._bz_mode = mode
# --> 266     super().__init__(name, mode)
#
# File ~/miniconda3/envs/work/lib/python3.9/bz2.py:85, in BZ2File.__init__(self, filename, mode, compresslevel)
#      82     raise ValueError("Invalid mode: %r" % (mode,))
#      84 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 85     self._fp = _builtin_open(filename, mode)
#      86     self._closefp = True
#      87     self._mode = mode_code
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mix.pdb'

# %% [markdown]
# With MDAnalysis it is very easy to select a group of atoms, which can then be used to for the analysis.

# %%
atoms = sys.select_atoms("all")
numberOfAtoms = len(atoms.positions)
print(" Number of Atoms : %4i" % numberOfAtoms)

# %% [markdown]
# Although we don't need the have the atomic charges for our analysis, we need to define them this to avoid errors later

# %%
sys.add_TopologyAttr('charge', [0]*numberOfAtoms)

# %% [markdown]
# It is then easy to access information frame by frame by looping over the _system trajectory_ object. For example we can print the cell dimensions and the coordinates of the first atom.

# %%
for iFrame in sys.trajectory:
    boxSize = np.array(sys.dimensions[0:3])
    print("Frame : %2i" % iFrame.frame)
    print("Cell dimensions [Angstroms]       : %8.3f %8.3f %8.3f" % 
        (boxSize[X],boxSize[Y],boxSize[Z]) )
    print("Coordinates of atom 1 [Angstroms] : %8.3f %8.3f %8.3f" % 
         (atoms.positions[0,X],atoms.positions[0,Y],atoms.positions[0,Z]) )
    print("---")
    if iFrame.frame == 2: break

# %% [markdown]
# We can then visualise the trajectory using nglview, which can directly read the MDAnalysis _system_.

# %%
view = ng.show_mdanalysis(sys, gui=True)
view.center()
view.representations = [
    {"type": "spacefill", "params": {"sele": "all"}},
    {"type": "unitcell", "params": {"sele": "all"}}
]
view.camera = 'orthographic'
view

# %% [markdown]
# Another type of analysis that we ca do is to compute the density profile along the crystallographic directions. This can be readily done using the **lineardensity** function in the MDAnalysis package.

# %%
from MDAnalysis.analysis import lineardensity
ldens = lineardensity.LinearDensity(atoms,binsize=.2,verbose=True)
dmap = ldens.run()

x = list(np.arange(0,dmap.dimensions[X],dmap.binsize))

nx = len(x)-1

print(nx,ny,nz)
fig = plt.figure()
ax = fig.gca()

ax.plot(x[0:nx],dmap.results.x.pos[0:nx])

plt.show()

# %% [markdown]
# Alternatively, we could compute the atoms' density manually by looping over the frames and use the Numpy histogram function.

# %%
histo = np.zeros(180, dtype=float)
for iFrame in sys.trajectory:
    y, x = np.histogram(atoms.positions[:,X], bins=180, range=(0.,180.))
    histo[:] = histo[:] + y
histo /= nFrames

fig = plt.figure()
ax = fig.gca()
ax.plot(x[0:-1],histo)
plt.show()
