# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("results.csv", sep=",")

x = data.iloc[:, 0]
y = data.iloc[:, 1]
# print(data)
plt.plot(y)

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.gca()
ax.plot(x,y)

i0 = 0
i1 = 15
i2 = 30
i3 = len(data)-1

print(i0,i1,i2,i3)
fit1 = np.polyfit(x[i0:i1],y[i0:i1],1)
line1 = np.poly1d(fit1)
y1 = line1(x)

fit2 = np.polyfit(x[i2:i3],y[i2:i3],1)
line2 = np.poly1d(fit2)
y2 = line2(x)

ax.plot(x,y1,c='red')
ax.plot(x,y2,c='green')

plt.show()

print(fit1)
print(fit2)
# Out:
# 0 15 30 49
# [9.50131422e-02 2.95607776e+02]
# [1.69120246e-01 2.97102064e+02]

# %%
ti = line1(2.5)
tf = line2(2.5)
print(ti,tf,tf-ti)
# Out:
# 295.8453092640382 297.52486482744666 1.6795555634084849
