# %% [markdown]
# # Click "Edit App" to start coding

# %%
# python packages
from sys import stdout
import pandas as pd # Dataframes and reading CSV files
import numpy as np # Numerical libraries
import math # Alternative numerical libraries
import matplotlib.pyplot as plt # Plotting library
# %matplotlib notebook
from lmfit import Model # Least squares fitting library

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#    return false;
# }

# %%
data = pd.read_csv("results.csv")
data.columns=("X","Y")
print(data)
print(data["Y"].size)

print("Average :",np.mean(data.iloc[:,1]))
print("StDev.  :",np.std(data["Y"]))
# Out:
#          X          Y
# 0      0.0  15.466586
# 1      1.0  20.507534
# 2      2.0  20.878779
# 3      3.0  19.368591
# 4      4.0  17.695586
# ..     ...        ...
# 995  995.0  24.546653
# 996  996.0  19.756408
# 997  997.0  23.768409
# 998  998.0  19.250526
# 999  999.0  18.772048
#
# [1000 rows x 2 columns]
# 1000
# Average : 19.940521792155277
# StDev.  : 2.0170402663408113

# %%
avg = np.sum(data.iloc[:,1])
# for val in data.iloc[:,1]:
#     avg = avg + val
avg = avg / data["Y"].size
print(avg)

fig1, ax = plt.subplots(figsize=(6,4))

ax.scatter(data["X"],data["Y"])
ax.axhline(y=avg, color='r', linestyle=':')

fig1.show()
# Out:
# 19.94052179215529
# <img src="data:image/png;base64,..." width="600">

# %%
histo , bins = np.histogram(data["Y"],bins=50)
fig2 , ax = plt.subplots(figsize=(6,4))

ax.bar(bins[:-1],histo,width=0.1,edgecolor='black')
fig2.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
